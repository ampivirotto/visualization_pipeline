# %%
import _pickle as cPickle
import ipyrad.analysis as ipa
import pandas as pd
import toyplot

# %%
pca = ipa.pca(
    data="./analysis-vcf2hdf5/popgen_data.snps.hdf5",
    mincov=1.0,
    impute_method='None'
)

## run pCA
pca.run(nreplicates=25, seed=14)
pca.draw(0, 1)
# Out:
# Samples: 62
# Sites before filtering: 715871
# Filtered (indels): 0
# Filtered (bi-allel): 13
# Filtered (mincov): 264483
# Filtered (minmap): 0
# Filtered (combined): 264493
# Sites after filtering: 451378
# Sites containing missing values: 0 (0.00%)
# Missing values in SNP matrix: 0 (0.00%)
# Subsampling SNPs: 187235/451378
# (<toyplot.canvas.Canvas at 0x7ff56cc5c3c8>,
# ...
#  <toyplot.mark.Point at 0x7ff56c1e1748>)
# ...
